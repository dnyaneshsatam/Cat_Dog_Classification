# %%
import numpy as np
import keras
import glob
import os
import random
import matplotlib.pyplot as plt
import datetime
import cv2
# %matplotlib inline

# %%
from google.colab import drive
drive.mount('/content/drive',force_remount=True)
# Out:
# Mounted at /content/drive

# %%
## Generating data

img_width = 100
img_height = 100
img_channel = 3
batch_size = 40

cls = ['cats','dogs']
train_cls_label = {}
train_img_path = []

test_cls_label = {}
test_img_path = []


dataset_path = '/content/drive/My Drive/Colab Notebooks/catdog_dataset/training_set'

for i,cd_class in enumerate(cls):
    path = glob.glob(os.path.join(dataset_path,cd_class,'*'))
    train_img_path = train_img_path + path
    train_cls_label.update({p:i for p in path})

print('train_img_path',len(train_img_path))
print('train_cls_label',len(train_cls_label))
    
dataset_path = '/content/drive/My Drive/Colab Notebooks/catdog_dataset/test_set'
path = []

for i,cd_class in enumerate(cls):
    path = glob.glob(os.path.join(dataset_path,cd_class,'*'))
    test_img_path = test_img_path + path
    test_cls_label.update({p:i for p in path})

print('test_img_path',len(test_img_path))
print('test_cls_label',len(test_cls_label))

train_keys = list(train_cls_label.keys())
test_keys = list(test_cls_label.keys())

random.shuffle(train_keys)
random.shuffle(test_keys)

# To limit 
#train_keys = train_keys #[:4000]
#test_keys = test_keys  #[:2000]

final_train = {}
final_test = {}

final_train.update({p:train_cls_label[p] for p in train_keys})
final_test.update({p:test_cls_label[p] for p in test_keys})
# Out:
# train_img_path 8000
# train_cls_label 8000
# test_img_path 2000
# test_cls_label 2000

# %%
print('final_train',len(final_train))
print('final_test',len(final_test))
# Out:
# final_train 8000
# final_test 2000

# %%
## Define Generator

def generator(dict_cls,batch_size):

  while True:
    
    start_position = 0
    end_position = batch_size

    dict_cls_key = list(dict_cls.keys())

    num_batches = len(dict_cls)//batch_size

    for batch in range(num_batches):
      batch_data = np.zeros((batch_size,img_height,img_width,3))
      batch_label = np.zeros((batch_size,2))

      
      dict_cls_batch_key = dict_cls_key[start_position:end_position]

      for index in range(batch_size):

        image = cv2.imread(dict_cls_batch_key[index])
        image = image[0:image.shape[0]-15,15:image.shape[1]-15]
        image = cv2.resize(image,(img_height,img_width))

        image = image/255
        #print(dict_cls_batch_key[index])
        batch_data[index,:,:,:] = image
        batch_label[index] = keras.utils.to_categorical(dict_cls[dict_cls_batch_key[index]],num_classes=2,dtype='int32')


      start_position = end_position
      end_position = end_position + batch_size
      #print('----------------------------------------------')
      yield batch_data , batch_label

# %%
train_generator = generator(final_train,batch_size)
val_generator = generator(final_test,batch_size)

# %%
import keras
from keras.models import Sequential , Model
from keras.layers import Dense, Dropout, Activation, Flatten ,BatchNormalization
from keras.layers import Conv2D, MaxPooling2D
from keras import optimizers
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau

# %%
num_classes = 2
num_epochs = 25

# %%
model = Sequential()
model.add(Conv2D(32,(3, 3), padding='same',input_shape=(img_height,img_width,3)))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(Conv2D(32,(3, 3)))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(64,(3, 3), padding='same'))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(Conv2D(64,(3, 3)))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(128, (3, 3), padding='same'))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(Conv2D(128, (3, 3)))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(256))
model.add(Activation('relu'))
model.add(Dropout(0.5))
#model.add(Dense(64))
#model.add(Activation('relu'))
#model.add(Dropout(0.5))
model.add(Dense(num_classes))
model.add(Activation('softmax'))

# %%
# summary
#opt = optimizers.SGD(learning_rate=0.01,momentum=0.9,nesterov=True)
model.compile(optimizer='Adam',loss='categorical_crossentropy',metrics=['categorical_accuracy'])
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_15 (Conv2D)           (None, 100, 100, 32)      896
# _________________________________________________________________
# activation_21 (Activation)   (None, 100, 100, 32)      0
# _________________________________________________________________
# batch_normalization_15 (Batc (None, 100, 100, 32)      128
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 98, 98, 32)        9248
# _________________________________________________________________
# activation_22 (Activation)   (None, 98, 98, 32)        0
# _________________________________________________________________
# batch_normalization_16 (Batc (None, 98, 98, 32)        128
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 49, 49, 32)        0
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 49, 49, 32)        0
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 49, 49, 64)        18496
# _________________________________________________________________
# activation_23 (Activation)   (None, 49, 49, 64)        0
# _________________________________________________________________
# batch_normalization_17 (Batc (None, 49, 49, 64)        256
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 47, 47, 64)        36928
# _________________________________________________________________
# activation_24 (Activation)   (None, 47, 47, 64)        0
# _________________________________________________________________
# batch_normalization_18 (Batc (None, 47, 47, 64)        256
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 23, 23, 64)        0
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 23, 23, 64)        0
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 23, 23, 128)       73856
# _________________________________________________________________
# activation_25 (Activation)   (None, 23, 23, 128)       0
# _________________________________________________________________
# batch_normalization_19 (Batc (None, 23, 23, 128)       512
# _________________________________________________________________
# conv2d_20 (Conv2D)           (None, 21, 21, 128)       147584
# _________________________________________________________________
# activation_26 (Activation)   (None, 21, 21, 128)       0
# _________________________________________________________________
# batch_normalization_20 (Batc (None, 21, 21, 128)       512
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 10, 10, 128)       0
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 10, 10, 128)       0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 12800)             0
# _________________________________________________________________
# dense_6 (Dense)              (None, 256)               3277056
# _________________________________________________________________
# activation_27 (Activation)   (None, 256)               0
# _________________________________________________________________
# dropout_15 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 2)                 514
# _________________________________________________________________
# activation_28 (Activation)   (None, 2)                 0
# =================================================================
# Total params: 3,566,370
# Trainable params: 3,565,474
# Non-trainable params: 896
# _________________________________________________________________

# %%
if (len(final_train)%batch_size) == 0:
    steps_per_epoch = int(len(final_train)/batch_size)
else:
    steps_per_epoch = (len(final_train)//batch_size) + 1

if (len(final_test)%batch_size) == 0:
    validation_steps = int(len(final_test)/batch_size)
else:
    validation_steps = (len(final_test)//batch_size) + 1

# %%
LR = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=3, min_lr=0.00001) # write the REducelronplateau code here

curr_dt_time = datetime.datetime.now()
model_name = 'model_init' + '_' + str(curr_dt_time).replace(' ','').replace(':','_') + '/'
    
if not os.path.exists(model_name):
  os.mkdir(model_name)
        
filepath = model_name + 'model-{epoch:05d}-{loss:.5f}-{categorical_accuracy:.5f}-{val_loss:.5f}-{val_categorical_accuracy:.5f}.h5'

checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, save_weights_only=False, mode='auto', period=1)

callbacks_list = [checkpoint,LR]
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %%
model.fit_generator(train_generator, steps_per_epoch=steps_per_epoch,epochs=num_epochs,verbose=1, callbacks=callbacks_list,validation_data=val_generator,validation_steps=validation_steps)
# Out:
# Epoch 1/25
# 200/200 [==============================] - ETA: 0s - loss: 1.1452 - categorical_accuracy: 0.5829
# Epoch 00001: val_loss improved from inf to 1.50519, saving model to model_init_2020-08-0607_14_49.980946/model-00001-1.14518-0.58288-1.50519-0.50050.h5
# 200/200 [==============================] - 77s 387ms/step - loss: 1.1452 - categorical_accuracy: 0.5829 - val_loss: 1.5052 - val_categorical_accuracy: 0.5005
# Epoch 2/25
# 200/200 [==============================] - ETA: 0s - loss: 0.6308 - categorical_accuracy: 0.6441
# Epoch 00002: val_loss improved from 1.50519 to 0.66626, saving model to model_init_2020-08-0607_14_49.980946/model-00002-0.63081-0.64412-0.66626-0.61350.h5
# 200/200 [==============================] - 75s 376ms/step - loss: 0.6308 - categorical_accuracy: 0.6441 - val_loss: 0.6663 - val_categorical_accuracy: 0.6135
# Epoch 3/25
# 200/200 [==============================] - ETA: 0s - loss: 0.5940 - categorical_accuracy: 0.6825
# Epoch 00003: val_loss improved from 0.66626 to 0.61367, saving model to model_init_2020-08-0607_14_49.980946/model-00003-0.59404-0.68250-0.61367-0.66150.h5
# 200/200 [==============================] - 75s 375ms/step - loss: 0.5940 - categorical_accuracy: 0.6825 - val_loss: 0.6137 - val_categorical_accuracy: 0.6615
# Epoch 4/25
# 200/200 [==============================] - ETA: 0s - loss: 0.5959 - categorical_accuracy: 0.6925
# Epoch 00004: val_loss improved from 0.61367 to 0.53299, saving model to model_init_2020-08-0607_14_49.980946/model-00004-0.59588-0.69250-0.53299-0.72800.h5
# 200/200 [==============================] - 75s 377ms/step - loss: 0.5959 - categorical_accuracy: 0.6925 - val_loss: 0.5330 - val_categorical_accuracy: 0.7280
# Epoch 5/25
# 200/200 [==============================] - ETA: 0s - loss: 0.5373 - categorical_accuracy: 0.7326
# Epoch 00005: val_loss improved from 0.53299 to 0.52856, saving model to model_init_2020-08-0607_14_49.980946/model-00005-0.53734-0.73263-0.52856-0.72350.h5
# 200/200 [==============================] - 78s 389ms/step - loss: 0.5373 - categorical_accuracy: 0.7326 - val_loss: 0.5286 - val_categorical_accuracy: 0.7235
# Epoch 6/25
# 200/200 [==============================] - ETA: 0s - loss: 0.4850 - categorical_accuracy: 0.7678
# Epoch 00006: val_loss did not improve from 0.52856
# 200/200 [==============================] - 75s 375ms/step - loss: 0.4850 - categorical_accuracy: 0.7678 - val_loss: 0.5656 - val_categorical_accuracy: 0.7090
# Epoch 7/25
# 200/200 [==============================] - ETA: 0s - loss: 0.4774 - categorical_accuracy: 0.7788
# Epoch 00007: val_loss did not improve from 0.52856
# 200/200 [==============================] - 75s 376ms/step - loss: 0.4774 - categorical_accuracy: 0.7788 - val_loss: 0.7096 - val_categorical_accuracy: 0.6495
# Epoch 8/25
# 200/200 [==============================] - ETA: 0s - loss: 0.4356 - categorical_accuracy: 0.7966
# Epoch 00008: val_loss improved from 0.52856 to 0.46137, saving model to model_init_2020-08-0607_14_49.980946/model-00008-0.43558-0.79663-0.46137-0.78950.h5
# 200/200 [==============================] - 76s 378ms/step - loss: 0.4356 - categorical_accuracy: 0.7966 - val_loss: 0.4614 - val_categorical_accuracy: 0.7895
# Epoch 9/25
# 200/200 [==============================] - ETA: 0s - loss: 0.3940 - categorical_accuracy: 0.8200
# Epoch 00009: val_loss did not improve from 0.46137
# 200/200 [==============================] - 77s 385ms/step - loss: 0.3940 - categorical_accuracy: 0.8200 - val_loss: 0.4958 - val_categorical_accuracy: 0.7890
# Epoch 10/25
# 200/200 [==============================] - ETA: 0s - loss: 0.3559 - categorical_accuracy: 0.8391
# Epoch 00010: val_loss did not improve from 0.46137
# 200/200 [==============================] - 75s 376ms/step - loss: 0.3559 - categorical_accuracy: 0.8391 - val_loss: 0.4862 - val_categorical_accuracy: 0.7825
# Epoch 11/25
# 200/200 [==============================] - ETA: 0s - loss: 0.3446 - categorical_accuracy: 0.8455
# Epoch 00011: val_loss improved from 0.46137 to 0.43633, saving model to model_init_2020-08-0607_14_49.980946/model-00011-0.34456-0.84550-0.43633-0.82250.h5
# 200/200 [==============================] - 75s 376ms/step - loss: 0.3446 - categorical_accuracy: 0.8455 - val_loss: 0.4363 - val_categorical_accuracy: 0.8225
# Epoch 12/25
# 200/200 [==============================] - ETA: 0s - loss: 0.3055 - categorical_accuracy: 0.8600
# Epoch 00012: val_loss improved from 0.43633 to 0.41952, saving model to model_init_2020-08-0607_14_49.980946/model-00012-0.30551-0.86000-0.41952-0.81800.h5
# 200/200 [==============================] - 76s 378ms/step - loss: 0.3055 - categorical_accuracy: 0.8600 - val_loss: 0.4195 - val_categorical_accuracy: 0.8180
# Epoch 13/25
# 200/200 [==============================] - ETA: 0s - loss: 0.2904 - categorical_accuracy: 0.8730
# Epoch 00013: val_loss did not improve from 0.41952
# 200/200 [==============================] - 78s 391ms/step - loss: 0.2904 - categorical_accuracy: 0.8730 - val_loss: 0.4623 - val_categorical_accuracy: 0.8180
# Epoch 14/25
# 200/200 [==============================] - ETA: 0s - loss: 0.2569 - categorical_accuracy: 0.8878
# Epoch 00014: val_loss did not improve from 0.41952
# 200/200 [==============================] - 76s 380ms/step - loss: 0.2569 - categorical_accuracy: 0.8878 - val_loss: 0.4958 - val_categorical_accuracy: 0.8055
# Epoch 15/25
# 200/200 [==============================] - ETA: 0s - loss: 0.2316 - categorical_accuracy: 0.8991
# Epoch 00015: val_loss did not improve from 0.41952
# 200/200 [==============================] - 76s 380ms/step - loss: 0.2316 - categorical_accuracy: 0.8991 - val_loss: 0.4279 - val_categorical_accuracy: 0.8455
# Epoch 16/25
# 200/200 [==============================] - ETA: 0s - loss: 0.1728 - categorical_accuracy: 0.9260
# Epoch 00016: val_loss improved from 0.41952 to 0.36029, saving model to model_init_2020-08-0607_14_49.980946/model-00016-0.17278-0.92600-0.36029-0.88300.h5
# 200/200 [==============================] - 76s 380ms/step - loss: 0.1728 - categorical_accuracy: 0.9260 - val_loss: 0.3603 - val_categorical_accuracy: 0.8830
# Epoch 17/25
# 200/200 [==============================] - ETA: 0s - loss: 0.1343 - categorical_accuracy: 0.9413
# Epoch 00017: val_loss did not improve from 0.36029
# 200/200 [==============================] - 78s 391ms/step - loss: 0.1343 - categorical_accuracy: 0.9413 - val_loss: 0.4006 - val_categorical_accuracy: 0.8860
# Epoch 18/25
# 200/200 [==============================] - ETA: 0s - loss: 0.1214 - categorical_accuracy: 0.9499
# Epoch 00018: val_loss did not improve from 0.36029
# 200/200 [==============================] - 76s 380ms/step - loss: 0.1214 - categorical_accuracy: 0.9499 - val_loss: 0.4054 - val_categorical_accuracy: 0.8805
# Epoch 19/25
# 200/200 [==============================] - ETA: 0s - loss: 0.1067 - categorical_accuracy: 0.9550
# Epoch 00019: val_loss did not improve from 0.36029
# 200/200 [==============================] - 76s 380ms/step - loss: 0.1067 - categorical_accuracy: 0.9550 - val_loss: 0.4342 - val_categorical_accuracy: 0.8885
# Epoch 20/25
# 200/200 [==============================] - ETA: 0s - loss: 0.0911 - categorical_accuracy: 0.9617
# Epoch 00020: val_loss did not improve from 0.36029
# 200/200 [==============================] - 76s 381ms/step - loss: 0.0911 - categorical_accuracy: 0.9617 - val_loss: 0.4373 - val_categorical_accuracy: 0.8895
# Epoch 21/25
# 200/200 [==============================] - ETA: 0s - loss: 0.0840 - categorical_accuracy: 0.9668
# Epoch 00021: val_loss did not improve from 0.36029
# 200/200 [==============================] - 78s 391ms/step - loss: 0.0840 - categorical_accuracy: 0.9668 - val_loss: 0.4164 - val_categorical_accuracy: 0.8925
# Epoch 22/25
# 200/200 [==============================] - ETA: 0s - loss: 0.0809 - categorical_accuracy: 0.9646
# Epoch 00022: val_loss did not improve from 0.36029
# 200/200 [==============================] - 76s 380ms/step - loss: 0.0809 - categorical_accuracy: 0.9646 - val_loss: 0.4443 - val_categorical_accuracy: 0.8885
# Epoch 23/25
# 200/200 [==============================] - ETA: 0s - loss: 0.0764 - categorical_accuracy: 0.9672
# Epoch 00023: val_loss did not improve from 0.36029
# 200/200 [==============================] - 76s 379ms/step - loss: 0.0764 - categorical_accuracy: 0.9672 - val_loss: 0.4360 - val_categorical_accuracy: 0.8880
# Epoch 24/25
# 200/200 [==============================] - ETA: 0s - loss: 0.0803 - categorical_accuracy: 0.9674
# Epoch 00024: val_loss did not improve from 0.36029
# 200/200 [==============================] - 76s 378ms/step - loss: 0.0803 - categorical_accuracy: 0.9674 - val_loss: 0.4305 - val_categorical_accuracy: 0.8900
# Epoch 25/25
# 200/200 [==============================] - ETA: 0s - loss: 0.0783 - categorical_accuracy: 0.9665
# Epoch 00025: val_loss did not improve from 0.36029
# 200/200 [==============================] - 77s 387ms/step - loss: 0.0783 - categorical_accuracy: 0.9665 - val_loss: 0.4288 - val_categorical_accuracy: 0.8900
